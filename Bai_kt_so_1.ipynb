# %%
import numpy as np
import pandas as pd1

dic1 = {'Sản lượng kWh':['0-50','51-100','101-200','201-300','301-400','Trên 400'],'Giá điện đồng kWh':[1678,1734,2014,2536,2834,2927]}
df1 = pd.DataFrame(dic1, index = ['Bậc thang 1','Bậc thang 2','Bậc thang 3','Bậc thang 4','Bậc thang 5','Bậc thang 6'], columns =['Sản lượng kWh','Giá điện đồng kWh'])
display(df1)

def calculateBill(units):
 
    if (units <= 51):
      
        return units * 1678;
     
    elif (units >= 51 and units <= 100):
     
        return units * 1734;
     
    elif (units >= 101 and units <= 200):
      
        return units * 2014;
     
    elif (units >= 201 and units <= 300):
     
        return units * 2536;
    
    elif (units >= 301 and units <= 400):
     
        return units * 2834;
    
    elif (units > 400):
     
        return units * 2927;
    
    return 0;
 
units = int(input(" Xin mời quý khách nhập sản lượng điện đã tiêu thụ "));
print(" Tổng tiền quý khách phải thanh toán là (đồng) :",calculateBill(units))
# Out:
#             Sản lượng kWh  Giá điện đồng kWh
# Bậc thang 1          0-50               1678
# Bậc thang 2        51-100               1734
# Bậc thang 3       101-200               2014
# Bậc thang 4       201-300               2536
# Bậc thang 5       301-400               2834
# Bậc thang 6      Trên 400               2927
#  Xin mời quý khách nhập sản lượng điện đã tiêu thụ  200
#  Tổng tiền quý khách phải thanh toán là (đồng) : 402800

# %%
import numpy as np
import pandas as pd

df2 = pd.read_csv("annual-enterprise-survey-2021-financial-year-provisional-csv.csv")

print("Khảo sát doanh nghiệp tài chính thường niên 2021:")
display(df.head(500))

print("Thống Kê Lượng Tăng Trưởng Tài Chính Năm 2021")
df2.plot()

print("=> Lượng Tăng Trưởng Tài Chính Hằng Năm Giảm Mạnh")
# Out:
# Khảo sát doanh nghiệp tài chính thường niên 2021:
#      Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0    2021                     Level 1                99999
# 1    2021                     Level 1                99999
# 2    2021                     Level 1                99999
# 3    2021                     Level 1                99999
# 4    2021                     Level 1                99999
# ..    ...                         ...                  ...
# 495  2021                     Level 3                 CC15
# 496  2021                     Level 3                 CC15
# 497  2021                     Level 3                 CC15
# 498  2021                     Level 3                 CC15
# 499  2021                     Level 3                 CC15
#
#                            Industry_name_NZSIOC               Units  \
# 0                                All industries  Dollars (millions)
# ...
